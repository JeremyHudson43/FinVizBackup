# %%
import datetime as dt
from datetime import datetime
from datetime import date
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader as web
from dateutil.relativedelta import relativedelta

# %%
style.use("ggplot")

# %%
ticker = "RDCM"

# %%
three_months = datetime.today() + relativedelta(months=-3)
six_months = datetime.today() + relativedelta(months=-6)
last_year =  datetime.today() + relativedelta(months=-12)

# end = datetime.today().strftime('%Y-%m-%d')
end = datetime.today() + relativedelta(months=-1)

# %% [markdown]
# # One Year View

# %%
start = last_year.strftime('%Y-%m-%d')
df = web.get_data_yahoo(ticker, start, end)
plt.subplots(figsize=(20,10))
df["Adj Close"].plot()
plt.title(ticker)
plt.show()

# %% [markdown]
# # Six Month View

# %%
start = six_months.strftime('%Y-%m-%d')
df = web.get_data_yahoo(ticker, start, end)
plt.subplots(figsize=(20,10))
df["Adj Close"].plot()
plt.title(ticker)
plt.show()

# %% [markdown]
# ## Three Month View

# %%
start = three_months.strftime('%Y-%m-%d')
df = web.get_data_yahoo(ticker, start, end)
plt.subplots(figsize=(20,10))
df["Adj Close"].plot()
plt.title(ticker)
plt.show()

# %% [markdown]
# ## Check Answer

# %%
start = three_months.strftime('%Y-%m-%d')
end = datetime.today()
df = web.get_data_yahoo(ticker, start, end)
plt.subplots(figsize=(20,10))
df["Adj Close"].plot()
plt.title(ticker)
plt.show()
